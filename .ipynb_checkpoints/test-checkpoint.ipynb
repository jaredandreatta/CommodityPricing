# %%
import yfinance as yf
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from price_data import get_price_data, gpd_help

# %%
gpd_help()
# Out:
#   Commodity Futures Ticker
# 0              Gold   GC=F
# 1            Silver   SI=F
# 2          Platinum   PL=F
# 3            Copper   HG=F
# 4         Palladium   PA=F
# 5         Crude Oil   CL=F
# 6       Heating Oil   HO=F
# 7       Natural Gas   NG=F
# 8     RBOB Gasoline   RB=F

# %%
df=get_price_data('CL=F')
df.columns='Adj Close'
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2000-08-23    32.049999
# 2000-08-24    31.629999
# 2000-08-25    32.049999
# 2000-08-28    32.869999
# 2000-08-29    32.720001
#                 ...
# 2024-05-24    77.720001
# 2024-05-28    79.830002
# 2024-05-29    79.230003
# 2024-05-30    77.910004
# 2024-05-31    76.989998
# Name: Adj Close, Length: 5969, dtype: float64

# %%
plt.figure(figsize=(20,6))
plt.plot(df, c='black')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
